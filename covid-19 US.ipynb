# %% [markdown]
# # COVID_19

# %% [markdown]
# Importing necessary library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


#importing warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
df=pd.read_csv('covid_19_us.csv')
df.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-05-21 02:32:54  32.3182  -86.9023
# 1          Alaska             US  2020-05-21 02:32:54  61.3707 -152.4044
# 2  American Samoa             US  2020-05-21 02:32:54 -14.2710 -170.1320
# 3         Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 4        Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      13052     522        NaN  12530.0     1     266.194321       164450.0
# 1        401      10      352.0     39.0     2      54.815493        37045.0
# 2          0       0        NaN      0.0    60       0.000000          124.0
# 3      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 4       5003     107     3852.0   1044.0     5     165.782801        96258.0
#
# ...

# %%
df.tail()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 53       Virginia             US  2020-05-21 02:32:54  37.7693  -78.1700
# 54     Washington             US  2020-05-21 02:32:54  47.4009 -121.4905
# 55  West Virginia             US  2020-05-21 02:32:54  38.4912  -80.9545
# 56      Wisconsin             US  2020-05-21 02:32:54  44.2685  -89.6165
# 57        Wyoming             US  2020-05-21 02:32:54  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 53      32908    1075     4523.0  27310.0    51     385.541875       212626.0
# 54      18971    1037        NaN  17934.0    53     249.130224       293120.0
# 55       1567      69      950.0    548.0    54      87.437024        80641.0
# 56      13413     481     7728.0   5204.0    55     230.367575       167713.0
# 57        787      11      528.0    248.0    56     135.980607        18840.0
#
# ...

# %%
#checking no.of rows and columns
df.shape
# Out:
# (58, 18)

# %% [markdown]
# This dataset contains 58 rows & 18 columns

# %%
#checking column names
df.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %% [markdown]
# # Column Description

# %% [raw]
# 1.Province_State - The name of the State within the USA.
# 2.Country_Region - The name of the Country (US).
# 3.Last_Update - The most recent date the file was pushed.
# 4.Lat - Latitude.
# 5.Long_ - Longitude.
# 6.Confirmed - Aggregated confirmed case count for the state.
# 7.Deaths - Aggregated Death case count for the state.
# 8.Recovered - Aggregated Recovered case count for the state.
# 9.Active - Aggregated confirmed cases that have not been resolved (Active = Confirmed - Recovered - Deaths).
# 10.FIPS - Federal Information Processing Standards code that uniquely identifies counties within the USA.
# 11.Incident_Rate - confirmed cases per 100,000 persons.
# 12.People_Tested - Total number of people who have been tested.
# 13.People_Hospitalized - Total number of people hospitalized.
# 14.Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
# 15.UID - Unique Identifier for each row entry.
# 16.ISO3 - Officialy assigned country code identifiers.
# 17.Testing_Rate - Total number of people tested per 100,000 persons.
# 18.Hospitalization_Rate - Total number of people hospitalized * 100/ Number of confirmed cases.

# %%
#checking the information of the column

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %%
#checking the datatype of various column
df.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %%
df.columns.groupby(df.dtypes)
# Out:
# {dtype('int64'): Index(['Confirmed', 'Deaths', 'FIPS', 'UID'], dtype='object'),
#  dtype('float64'): Index(['Lat', 'Long_', 'Recovered', 'Active', 'Incident_Rate', 'People_Tested',
#         'People_Hospitalized', 'Mortality_Rate', 'Testing_Rate',
#         'Hospitalization_Rate'],
#        dtype='object'),
#  dtype('O'): Index(['Province_State', 'Country_Region', 'Last_Update', 'ISO3'], dtype='object')}

# %% [raw]
# Observation:-
#
# 1.'Confirmed', 'Deaths', 'FIPS', 'UID' are of int64 datatype
#
# 2.'Lat', 'Long_', 'Recovered', 'Active', 'Incident_Rate', 'People_Tested','People_Hospitalized',
# 'Mortality_Rate', 'Testing_Rate','Hospitalization_Rate' are of float64 datatype
#
# 3.Province_State', 'Country_Region', 'Last_Update', 'ISO3 are of object datatype

# %%
df['Last_Update'].unique()
# Out:
# array(['2020-05-21 02:32:54'], dtype=object)

# %% [markdown]
# This dataset contains data  upto 21st May 2020

# %%
df['Country_Region'].nunique()
# Out:
# 1

# %%
df['FIPS'].nunique()
# Out:
# 58

# %%
df['UID'].nunique()
# Out:
# 58

# %%
df['ISO3'].nunique()
# Out:
# 6

# %%
#dropping unnecessary column
df.drop(['Country_Region','UID','ISO3','Last_Update','FIPS'],axis=1,inplace=True)

# %%
#checking for null values
df.isnull().values.any()
# Out:
# True

# %% [markdown]
# Here we see that null values are present in our dataset
#
# Now we check no. of null values present in particular column

# %%
df.isnull().sum()
# Out:
# Province_State           0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %% [raw]
# Observation:-
#
#     we see that many columns contains null value
#
# We can also see it via visualization with the help of heatmap

# %%
#visualisation

sns.heatmap(df.isnull())

# %%
#Imputing the misssing values with mean
from sklearn.impute import SimpleImputer
list=['Lat','Long_','Recovered','Incident_Rate','People_Tested','People_Hospitalized','Mortality_Rate','Testing_Rate','Hospitalization_Rate']

imp=SimpleImputer(strategy='mean')
for i in list:
    df[i]=imp.fit_transform(df[i].values.reshape(-1,1))

# %%
#now again checking for missing values

df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Now our null values is removed.We can see it via visualisation

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='tab20')

# %% [markdown]
# # Now our data is ready for visualization without any missing data

# %% [markdown]
# In this dataset ,target column is Deaths

# %%
df['Deaths'].unique()
# Out:
# array([  522,    10,     0,   747,   107,  3497,  1299,  3529,   310,
#          407,  2096,  1697,     3,     5,    17,    77,  4525,  1864,
#          393,   202,   376,  2608,    73,  2123,  6066,  5060,   786,
#          570,   640,    16,   138,   377,   190, 10749,   283, 28636,
#          726,    49,     2,  1781,   299,   144,  4770,   125,   538,
#           46,   305,  1426,    90,    54,     6,  1075,  1037,    69,
#          481,    11], dtype=int64)

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  58.000000   58.000000      58.000000     58.000000     58.000000
# mean   36.840089  -85.206614   26756.086207   1611.017241   7007.428571
# std    10.694329   48.873770   52562.031122   4084.750891   9901.304545
# min   -14.271000 -170.132000       0.000000      0.000000     13.000000
# 25%    34.872800  -99.697700    2596.000000     74.000000   1281.750000
# 50%    38.978600  -86.797300   10148.500000    385.000000   4987.000000
# 75%    42.214075  -77.072550   29395.500000   1394.250000   7007.428571
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active  Incident_Rate  People_Tested  People_Hospitalized  \
# count      58.000000      58.000000   5.800000e+01            58.000000
# mean    20070.724138     396.230806   2.258534e+05          4897.454545
# std     41294.705318     395.554852   2.934948e+05          9879.577790
# ...

# %% [raw]
# Observation:-
#
# 1.Minimum latitude is -14.27100 & maxm is 61.370700
# 2.Minimum longitude is -170.132 & maxm is 145.67
# 3.Maxm confirmed cases is 354370.00
# 4.Maximum death count is 28636
# 5.In many column ,there is large difference between 75% & maxm,which means outliers are present

# %% [markdown]
# # check correlation

# %%
df.corr()
# Out:
#                            Lat     Long_  Confirmed    Deaths  Recovered  \
# Lat                   1.000000 -0.278274   0.120391  0.119685   0.030196
# Long_                -0.278274  1.000000   0.009951  0.028690  -0.041588
# Confirmed             0.120391  0.009951   1.000000  0.982191   0.822547
# Deaths                0.119685  0.028690   0.982191  1.000000   0.830223
# Recovered             0.030196 -0.041588   0.822547  0.830223   1.000000
# Active                0.119635  0.011604   0.985218  0.954378   0.725085
# Incident_Rate         0.245693  0.041318   0.708436  0.710105   0.542795
# People_Tested         0.084769 -0.077781   0.824136  0.739634   0.711255
# People_Hospitalized   0.026456  0.079677   0.869267  0.908279   0.761829
# Mortality_Rate       -0.134906  0.297192   0.382537  0.427127   0.322160
# Testing_Rate          0.309579  0.190191   0.332464  0.344465   0.220597
# Hospitalization_Rate -0.066255  0.071381   0.287471  0.298225   0.231692
#
# ...

# %% [raw]
# Here we see corelation between columns
#
# For better clarity ,we can see it via visualization with the help of heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),fmt='.0%',annot=True)

# %% [raw]
# Observation:
#
# 1.mortality rate is positively correlated with long
# 2.Deaths is positively correlated with confirmed & recovered,active,incident_rate,people_tested,people_hospitalized
# 3.Testing rate is positively correlated with incident rate

# %%
plt.figure(figsize=(12,10))
df.drop('Deaths',axis=1).corrwith(df['Deaths']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title('correlation with target variable')
# Out:
# Text(0.5, 1.0, 'correlation with target variable')

# %% [markdown]
# Observation:
#
# 1.All column is positively correlated with the target variable
#
# 2.Out of all ,confirmed is highly correlated with Deaths

# %% [markdown]
# # Data Visualization

# %%
plt.hist(df["Lat"])
plt.xlabel('Latitude')
plt.ylabel('Frequency')
plt.title('Latitude - Histogram')
# Out:
# Text(0.5, 1.0, 'Latitude - Histogram')

# %% [markdown]
# Most of the province state fall in the Latitude range of 40-45 degrees

# %%
plt.hist(df["Long_"])
plt.xlabel('Longitude')
plt.title('Longitude - Histogram')
# Out:
# Text(0.5, 1.0, 'Longitude - Histogram')

# %% [markdown]
# Most of the province lie in the longitude range of -75 to -100

# %%
plt.hist(df["Confirmed"])
plt.xlabel('Confirmed Cases of COVID-19')
plt.title('Confirmed Cases - Histogram')
# Out:
# Text(0.5, 1.0, 'Confirmed Cases - Histogram')

# %% [markdown]
# highly skewed to the right

# %%
plt.hist(df["Incident_Rate"])
plt.xlabel('Incident_Rate')
plt.title('Incident_Rate - Histogram')
# Out:
# Text(0.5, 1.0, 'Incident_Rate - Histogram')

# %% [markdown]
# highly skewed to the right

# %%
max_confirmed_cases=df.sort_values(by='Confirmed',ascending=False)
max_confirmed_cases.head()
# Out:
#    Province_State      Lat     Long_  Confirmed  Deaths     Recovered  \
# 36       New York  42.1657  -74.9481     354370   28636  61886.000000
# 34     New Jersey  40.2989  -74.5210     150776   10749  23945.000000
# 17       Illinois  40.3495  -88.9861     100418    4525   7007.428571
# 25  Massachusetts  42.2302  -71.5301      88970    6066   7007.428571
# 5      California  36.1162 -119.6816      85997    3497   7007.428571
#
#       Active  Incident_Rate  People_Tested  People_Hospitalized  \
# 36  263848.0    1821.620216      1505836.0         76410.000000
# 34  116082.0    1697.509285       531343.0          4897.454545
# 17   95893.0     792.451219       642713.0          4897.454545
# 25   82904.0    1290.822797       489953.0          8897.000000
# 5    82500.0     217.646575      1380120.0          4897.454545
#
#     Mortality_Rate  Testing_Rate  Hospitalization_Rate
# 36        8.080819   7740.670204             21.562209
# ...

# %%
sns.barplot(x='Province_State',y='Confirmed',data=max_confirmed_cases.head())
plt.show()

# %%
max_death=df.sort_values(by='Deaths',ascending=False)
max_death.head()
# Out:
#    Province_State      Lat    Long_  Confirmed  Deaths     Recovered  \
# 36       New York  42.1657 -74.9481     354370   28636  61886.000000
# 34     New Jersey  40.2989 -74.5210     150776   10749  23945.000000
# 25  Massachusetts  42.2302 -71.5301      88970    6066   7007.428571
# 26       Michigan  43.3266 -84.5361      53009    5060  28234.000000
# 43   Pennsylvania  40.5908 -77.2098      68126    4770   7007.428571
#
#       Active  Incident_Rate  People_Tested  People_Hospitalized  \
# 36  263848.0    1821.620216      1505836.0         76410.000000
# 34  116082.0    1697.509285       531343.0          4897.454545
# 25   82904.0    1290.822797       489953.0          8897.000000
# 26   19715.0     530.787614       437072.0          4897.454545
# 43   63356.0     532.151684       349700.0          4897.454545
#
#     Mortality_Rate  Testing_Rate  Hospitalization_Rate
# 36        8.080819   7740.670204             21.562209
# ...

# %%
sns.barplot(x='Province_State',y='Deaths',data=max_death.head())

# %%
max_recovered=df.sort_values(by='Recovered',ascending=False)
max_recovered.head()
# Out:
#    Province_State      Lat    Long_  Confirmed  Deaths  Recovered    Active  \
# 36       New York  42.1657 -74.9481     354370   28636    61886.0  263848.0
# 49          Texas  31.0545 -97.5635      51673    1426    30341.0   19906.0
# 26       Michigan  43.3266 -84.5361      53009    5060    28234.0   19715.0
# 22      Louisiana  31.1695 -91.8678      35316    2608    26249.0    6459.0
# 34     New Jersey  40.2989 -74.5210     150776   10749    23945.0  116082.0
#
#     Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  \
# 36    1821.620216      1505836.0         76410.000000        8.080819
# 49     178.208070       770241.0          4897.454545        2.759662
# 26     530.787614       437072.0          4897.454545        9.545549
# 22     759.680898       285970.0          4897.454545        7.384755
# 34    1697.509285       531343.0          4897.454545        7.129119
#
#     Testing_Rate  Hospitalization_Rate
# 36   7740.670204             21.562209
# ...

# %%
sns.barplot(x='Province_State',y='Recovered',data=max_recovered.head())

# %% [raw]
# OBSERVATION FROM ABOVE:
#
# 1.confirmed cases-Newyork reports the maxm no. of confirmed cases followed by newjercy iiilois
# 2.Death-Newyork report the maxm no. of death cases followed by New Jersey
# 3.Recovered-New York has the most no. of recovered casefollowed by Texax & Michigan

# %%
sns.lineplot(x=df['Confirmed'],y=df["Deaths"],data=df)
plt.show()

# %% [markdown]
# no. of deaths increases with increase in no. of co nfirmed cases

# %%
sns.lineplot(x=df['Active'],y=df["Recovered"],data=df)
plt.show()

# %% [markdown]
# observation:
#     when acive cases is low,recovery rate is high ,but suddenlt it decreases and then again recovery rate increses

# %%
plt.scatter(x=df['Active'],y=df['Deaths'])

# %% [markdown]
# no.of  death is high when active cases is between 0-50000

# %%
sns.relplot(x="Active",y='People_Hospitalized',kind='line',data=df)

# %%
plt.figure(figsize=(24,6))
sns.barplot(x="Province_State", y="Incident_Rate",data=df)
plt.xticks(rotation=90)
plt.title('Province/State wise Incident_Rate of COVID-19')
# Out:
# Text(0.5, 1.0, 'Province/State wise Incident_Rate of COVID-19')

# %% [markdown]
# Incident_Rate  is highest in New York followed by New Jeresy, Rhode Island, Massachusetts, Connecticut, District of Columbia

# %%
plt.figure(figsize=(24,10))
sns.barplot(x="Province_State", y="People_Tested",data=df)
plt.xticks(rotation=90)
plt.title('Province_State wise People_Tested for COVID-19')
# Out:
# Text(0.5, 1.0, 'Province_State wise People_Tested for COVID-19')

# %% [markdown]
# Number of People tested was highest in New York followed by California, Texas

# %%
plt.figure(figsize=(24,6))
sns.barplot(x="Province_State", y="People_Hospitalized",data=df)
plt.xticks(rotation=90)
plt.title('Province_State wise People_Hospitalized due to COVID-19')
# Out:
# Text(0.5, 1.0, 'Province_State wise People_Hospitalized due to COVID-19')

# %% [markdown]
# Number of People hospitalized was highest in New York followed by Connecticut, Massachusetts

# %%
plt.figure(figsize=(24,6))
sns.barplot(x="Province_State", y="Testing_Rate",data=df)
plt.xticks(rotation=90)
plt.title('Province_State wise Testing_Rate for COVID-19')
# Out:
# Text(0.5, 1.0, 'Province_State wise Testing_Rate for COVID-19')

# %% [markdown]
# Testing rate is highest in Rhode island followed by New York, North Dakota,

# %%
plt.scatter(x=df['Lat'],y=df['Deaths'])

# %% [markdown]
# most no. of death occur when latitude range is between 30-50

# %%
sns.scatterplot(x='Deaths',y='Hospitalization_Rate',data=df)

# %%
sns.scatterplot(x='Testing_Rate',y='Hospitalization_Rate',data=df)

# %% [markdown]
# # Checking skewness

# %%
df.drop(['Lat','Long_'],axis=1,inplace=True)

# %%
df.skew()
# Out:
# Confirmed               4.708614
# Deaths                  5.489201
# Recovered               3.647693
# Active                  4.180953
# Incident_Rate           1.988351
# People_Tested           2.829700
# People_Hospitalized     6.869437
# Mortality_Rate          0.496115
# Testing_Rate            1.313407
# Hospitalization_Rate    0.867341
# dtype: float64

# %%
#treating skewness via squareroot method and cube root method
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df[col].skew()>0.55:
            df[col]=np.sqrt(df[col])
        if df[col].skew()<-0.55:
            df[col]=np.cbrt(df[col])

# %%
df.skew()
# Out:
# Confirmed               1.901107
# Deaths                  2.496421
# Recovered               1.431056
# Active                  1.818910
# Incident_Rate           0.924150
# People_Tested           1.182962
# People_Hospitalized     3.148527
# Mortality_Rate          0.496115
# Testing_Rate           -0.261124
# Hospitalization_Rate    0.211792
# dtype: float64

# %% [markdown]
# # outliers detection

# %%
#transform non numeric column into numeric one
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Province_State']=le.fit_transform(df['Province_State'])

# %%
df.plot(kind='box',subplots=True,layout=(4,4),figsize=(15,10))
# Out:
# Province_State              AxesSubplot(0.125,0.71587;0.168478x0.16413)
# Confirmed                AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# Deaths                   AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# Recovered                AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# Active                     AxesSubplot(0.125,0.518913;0.168478x0.16413)
# Incident_Rate           AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# People_Tested           AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# People_Hospitalized     AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# Mortality_Rate             AxesSubplot(0.125,0.321957;0.168478x0.16413)
# Testing_Rate            AxesSubplot(0.327174,0.321957;0.168478x0.16413)
# Hospitalization_Rate    AxesSubplot(0.529348,0.321957;0.168478x0.16413)
# dtype: object

# %% [markdown]
# we see that outliers are present in our dataset,which needs to be removed

# %%
from scipy.stats import zscore
z_score=np.abs(zscore(df))
print(df.shape)

df_new=df.loc[(z_score<3).all(axis=1)]
print(df_new.shape)
# Out:
# (58, 11)
# (54, 11)

# %% [markdown]
# # model training

# %%
#spliting the data into input and output variable
x=df_new.drop('Hospitalization_Rate',axis=1)
x.shape
# Out:
# (54, 10)

# %%
y=df_new['Hospitalization_Rate']
y.shape
# Out:
# (54,)

# %%
#Scaling the input variable
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x=pd.DataFrame(x)

# %%
#lets again check skewness
x.skew()
# Out:
# 0    0.002127
# 1    1.067007
# 2    1.521222
# 3    0.816737
# 4    1.304322
# 5    0.804941
# 6    0.531680
# 7   -0.487540
# 8    0.485316
# 9    0.313904
# dtype: float64

# %%
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=.20)
    lg=LinearRegression()
    lg.fit(x_train,y_train)
    lg_pred=lg.predict(x_test)
    r2_scr=r2_score(y_test,lg_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print('max r2 score corresponding to ',final_r_state,'is',max_r_score)
# Out:
# max r2 score corresponding to  86 is 0.5876798064808331

# %%
#Breaking input and target variable into train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=86)

# %%
print('x_train_shape:',x_train.shape)
print('x_test_shape:',x_test.shape)
print('y_train_shape:',y_train.shape)
print('y_test_shape:',y_test.shape)
# Out:
# x_train_shape: (43, 10)
# x_test_shape: (11, 10)
# y_train_shape: (43,)
# y_test_shape: (11,)

# %%
#importing our models library
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#importing error metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for m in model:
    m.fit(x_train,y_train)
    print('score of ',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Error:')
    print('mean absolute error:',mean_absolute_error(y_test,predm))
    print('mean squared error:',mean_squared_error(y_test,predm))
    print('root mean squared error:',np.sqrt(mean_squared_error(y_test,predm)))
    print('r2 score:',r2_score(y_test,predm))
    print('************************************************************************************')
    print('\n')
# Out:
# score of  LinearRegression() is: 0.31620879274390534
# Error:
# mean absolute error: 0.2508242483176437
# mean squared error: 0.08837127025975247
# root mean squared error: 0.2972730567336241
# r2 score: 0.5876798064808331
# ************************************************************************************
#
#
# score of  DecisionTreeRegressor() is: 1.0
# Error:
# mean absolute error: 0.17686782663834608
# mean squared error: 0.07536149593894406
# root mean squared error: 0.2745204836418296
# r2 score: 0.6483804465172303
# ************************************************************************************
#
#
# score of  KNeighborsRegressor() is: 0.28115207127900665
# Error:
# mean absolute error: 0.19133470142953496
# mean squared error: 0.06380314118326386
# root mean squared error: 0.2525928367615833
# r2 score: 0.7023090938662743
# ************************************************************************************
#
#
# score of  SVR() is: 0.6331387140119684
# Error:
# ...

# %%
#cross validate the models
from sklearn.model_selection import cross_val_score
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for m in model:
    score=cross_val_score(m,x,y,cv=5,scoring='r2')
    print('score of ',m,'is:')
    print('score:',score)
    print('mean score:',score.mean())
    print('standard deviation:',score.std())
    print('******************************************************')
    print('\n')
# Out:
# score of  LinearRegression() is:
# score: [ 0.46646813  0.18619493 -1.66737356  0.25520542 -0.12217263]
# mean score: -0.17633554200765453
# standard deviation: 0.7690228193905736
# ******************************************************
#
#
# score of  DecisionTreeRegressor() is:
# score: [-0.69216054 -0.12367402 -1.69081089 -0.81964476 -0.47482661]
# mean score: -0.76022336270017
# standard deviation: 0.5216901334013357
# ******************************************************
#
#
# score of  KNeighborsRegressor() is:
# score: [-0.21722461  0.13239606 -1.64305981  0.56928698  0.04637453]
# mean score: -0.22244537019314467
# standard deviation: 0.7540808107194595
# ******************************************************
#
#
# score of  SVR() is:
# score: [0.41777983 0.27118125 0.04160519 0.33923588 0.33020636]
# mean score: 0.280001700493702
# standard deviation: 0.12800211483476132
# ******************************************************
#
#
# score of  Lasso() is:
# ...

# %%
#SVR is giving the best result,so finding its best parameter using GridSearchCV

from sklearn.model_selection import GridSearchCV

parameters={'kernel':['linear', 'poly', 'rbf', 'sigmoid'],'C':[1,10]}
svr=SVR()
clf=GridSearchCV(svr,parameters)
clf.fit(x,y)

print(clf.best_params_)
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
#using decision tree model with best paramters

svr=SVR(kernel='rbf',C=1)
svr.fit(x_train, y_train)

svr_pred = svr.predict(x_test)
print('score:',svr.score(x_train,y_train))
print('r2_score',r2_score(y_test,svr_pred))
print('mean_squared_error',mean_squared_error(y_test,svr_pred))
print('mean_absolute_error',mean_absolute_error(y_test,svr_pred))
# Out:
# score: 0.6331387140119684
# r2_score 0.8447328602091766
# mean_squared_error 0.03327791019838999
# mean_absolute_error 0.15869049396741816

# %% [markdown]
# # using ensemble technique to boostup our score

# %%
#using Adaboost
from sklearn.ensemble import AdaBoostRegressor

dtc=DecisionTreeRegressor()
ada=AdaBoostRegressor(base_estimator=svr,n_estimators=20,random_state=75)

ada.fit(x_train,y_train)
predada=ada.predict(x_test)
print('score:',ada.score(x_train,y_train))
print('r2_score',r2_score(y_test,predada))
print('mean_squared_error',mean_squared_error(y_test,predada))
print('mean_absolute_error',mean_absolute_error(y_test,predada))
# Out:
# score: 0.9088006832738933
# r2_score 0.661670872124735
# mean_squared_error 0.07251300146380424
# mean_absolute_error 0.23026632385833334

# %%
#plotting scatter plot between test data & predicted data for SVR

plt.scatter(y_test,svr_pred)
plt.xlabel('y_test')
plt.ylabel('predicted Y')
plt.title('scatter plot between test data and predicted data')
plt.show()

# %%
#saving AdaBoostRegressor

import joblib
joblib.dump(svr,'covid_19_US.pkl')
# Out:
# ['covid_19_US.pkl']
